# %%
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip

# Define the video path
video_path = r'C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\videoplayback.mp4'


# Define the time ranges to cut (in seconds)
time_ranges = [
    (35*60+6 + 1*60 + 47, 48*60+18 + 1*60 + 47),    # 00:36:53 to 00:50:05
    (103*60+46 + 1*60 + 47, 121*60+11 + 1*60 + 47), # 01:45:33 to 02:02:58
    (147*60+21 + 1*60 + 47, 164*60+33 + 1*60 + 47), # 02:29:08 to 02:46:20
    (193*60+58 + 1*60 + 47, 217*60+8 + 1*60 + 47),   # 03:15:45 to 03:39:55
    (243*60+33 + 1*60 + 47, 271*60+33 + 1*60 + 47), # 04:05:20 to 04:33:20
    (294*60+48 + 1*60 + 47, 312*60+41 + 1*60 + 47)  # 04:56:35 to 05:14:28
]
# Output directory
output_dir = r"C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match"

# Loop through the time ranges and cut the video
for i, (start_time, end_time) in enumerate(time_ranges):
    output_path = f"{output_dir}\\Cut_Match_{i+1}.mp4"
    ffmpeg_extract_subclip(video_path, start_time, end_time, targetname=output_path)
    print(f"Saved: {output_path}")

print("All clips have been saved.")
# Out:
#
# t:   0%|          | 2/47473 [00:53<354:36:54, 26.89s/it, now=None]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
#
#
# t:   0%|          | 2/47473 [03:00<1187:11:37, 90.03s/it, now=None]
# Moviepy - Command successful
# Saved: C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\Cut_Match_1.mp4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
#
#
# t:   0%|          | 2/47473 [03:55<1554:58:25, 117.92s/it, now=None]
# Moviepy - Command successful
# Saved: C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\Cut_Match_2.mp4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
#
#
# t:   0%|          | 2/47473 [04:35<1815:35:33, 137.69s/it, now=None]
# Moviepy - Command successful
# Saved: C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\Cut_Match_3.mp4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
#
#
# ...

# %%
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from moviepy.audio.io.AudioFileClip import AudioFileClip

# Define the video and audio paths
video_path = r'C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\Final.mp4'
audio_path = r'C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\Final.m4a'

# Define the new time ranges to cut (in seconds)
time_ranges = [
    (62*60+56, 79*60+11),   # 01:02:56 to 01:19:11
    (104*60+43, 115*60+51), # 01:44:43 to 01:55:51
    (137*60+50, 151*60+17), # 02:17:50 to 02:31:17
    (170*60+32, 184*60+42)  # 02:50:32 to 03:04:42
]

# Output directory for both video and audio
output_dir = r"C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\final_wildcard"

# Get the duration of the audio file
with AudioFileClip(audio_path) as audio_clip:
    audio_duration = audio_clip.duration

# Loop through the time ranges and cut both video and audio
for i, (start_time, end_time) in enumerate(time_ranges):
    if end_time > audio_duration:
        print(f"Skipping range ({start_time}, {end_time}) as it exceeds the audio duration ({audio_duration} seconds).")
        continue
    
    # Cut video
    video_output_path = f"{output_dir}\\wildcard_match{i+1}.mp4"
    ffmpeg_extract_subclip(video_path, start_time, end_time, targetname=video_output_path)
    print(f"Saved Video: {video_output_path}")
    
    # Cut audio
    audio_output_path = f"{output_dir}\\wildcard_match{i+1}.m4a"
    with AudioFileClip(audio_path) as audio_clip:
        audio_clip = audio_clip.subclip(start_time, end_time)
        audio_clip.write_audiofile(audio_output_path, codec='aac', bitrate='192k')
    print(f"Saved Audio: {audio_output_path}")

print("All clips have been saved.")
# Out:
#
# chunk:   0%|          | 1/21499 [37:56<13594:34:02, 2276.51s/it, now=None]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
#
# chunk:   0%|          | 1/21499 [38:37<13840:18:51, 2317.66s/it, now=None]
# Moviepy - Command successful
# Saved Video: C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\final_wildcard\wildcard_match1.mp4
#
# chunk:   0%|          | 1/21499 [38:38<13844:09:17, 2318.31s/it, now=None]
# MoviePy - Writing audio in C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\final_wildcard\wildcard_match1.m4a
#
#
# chunk:   0%|          | 1/21499 [38:53<13935:08:38, 2333.54s/it, now=None]
# MoviePy - Done.
# Saved Audio: C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\final_wildcard\wildcard_match1.m4a
# Moviepy - Running:
# >>> "+ " ".join(cmd)
#
# chunk:   0%|          | 1/21499 [39:02<13985:40:43, 2342.01s/it, now=None]
# ...

# %% [markdown]
# # **Test combined**

# %%
from moviepy.editor import VideoFileClip, AudioFileClip

# Paths to the video and audio files
video_path = r"C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\Cut_Match_2.mp4"
audio_path = r"C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\Cut_Match_2.m4a"

# Load the video file
video_clip = VideoFileClip(video_path)

# Load the audio file
audio_clip = AudioFileClip(audio_path)

# Set the audio of the video to the audio clip
final_video = video_clip.set_audio(audio_clip)

# Path to save the final video
output_path = r"C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\Combined_Cut_Match_2.mp4"

# Write the final video to a file
final_video.write_videofile(output_path, codec='libx264', audio_codec='aac')

print(f"Combined video saved to {output_path}")
# Out:
#
#
#
# t:   0%|          | 2/47473 [1:33:40<37056:58:44, 2810.24s/it, now=None]
#
#
#
# t:   0%|          | 2/47473 [1:33:40<37057:01:06, 2810.25s/it, now=None]
# Moviepy - Building video C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\Combined_Cut_Match_2.mp4.
# MoviePy - Writing audio in Combined_Cut_Match_2TEMP_MPY_wvf_snd.mp4
#
#
#
# t:   0%|          | 2/47473 [1:34:09<37249:43:13, 2824.86s/it, now=None]
#
#
#
# t:   0%|          | 2/47473 [1:34:09<37249:48:21, 2824.87s/it, now=None]
# MoviePy - Done.
# Moviepy - Writing video C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\Combined_Cut_Match_2.mp4
#
#
#
# t:   0%|          | 2/47473 [2:20:07<55434:05:32, 4203.89s/it, now=None]
# Moviepy - Done !
#
#
#
# t:   0%|          | 2/47473 [2:20:15<55484:23:25, 4207.70s/it, now=None]
# ...

# %%
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
from moviepy.audio.io.AudioFileClip import AudioFileClip

# Define the video and audio paths
video_path = r'C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\videoplayback.mp4'
audio_path = r'C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\videoplayback.m4a'

# Define the specific time ranges to cut (in seconds)
time_ranges = [
    (105*60+40, 124*60+5),  # 01:45:40 to 02:04:05
    (195*60+45, 219*60+55)  # 03:15:45 to 03:39:55
]

# Define the output filenames
output_filenames = [
    "newvid 2", "newvid 4",
    "newaud 2", "newaud 4"
]

# Output directory for both video and audio
output_dir = r"C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match"

# Loop through the time ranges and cut both video and audio
for i, (start_time, end_time) in enumerate(time_ranges):
    # Cut video
    video_output_path = f"{output_dir}\\{output_filenames[i]}.mp4"
    ffmpeg_extract_subclip(video_path, start_time, end_time, targetname=video_output_path)
    print(f"Saved Video: {video_output_path}")
    
    # Cut audio
    audio_output_path = f"{output_dir}\\{output_filenames[i+2]}.m4a"
    with AudioFileClip(audio_path) as audio_clip:
        audio_clip = audio_clip.subclip(start_time, end_time)
        audio_clip.write_audiofile(audio_output_path, codec='aac', bitrate='192k')
    print(f"Saved Audio: {audio_output_path}")

print("All clips have been saved.")
# Out:
#
#
#
# t:   0%|          | 2/47473 [2:39:44<63194:07:21, 4792.38s/it, now=None]
# Moviepy - Running:
# >>> "+ " ".join(cmd)
#
#
#
# t:   0%|          | 2/47473 [2:41:34<63916:21:15, 4847.15s/it, now=None]
# Moviepy - Command successful
# Saved Video: C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\newvid 2.mp4
#
#
#
# t:   0%|          | 2/47473 [2:41:34<63920:13:14, 4847.44s/it, now=None]
# MoviePy - Writing audio in C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\newaud 2.m4a
#
#
#
# t:   0%|          | 2/47473 [2:42:02<64103:17:47, 4861.32s/it, now=None]
#
#
#
# t:   0%|          | 2/47473 [2:42:02<64103:32:01, 4861.34s/it, now=None]
# MoviePy - Done.
# Saved Audio: C:\Users\Boy Cakaraningrat\Documents\GitHub\mobile-legend-analisis\Mobile-Legend-analisis\Cut_Match\newaud 2.m4a
# Moviepy - Running:
# >>> "+ " ".join(cmd)
#
#
#
# ...
