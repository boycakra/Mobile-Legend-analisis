# %%
import streamlit as st
import pygal
from pygal.style import LightSolarizedStyle
from collections import defaultdict
from statistics import mean
import pandas as pd
import base64
file_path = "Baru_matchDummy.csv"
data = pd.read_csv(file_path)

# %%
data
# Out:
#          Date     Stage  Match_id  Round          Team        Player  \
# 0   6/29/2024  Wildcard     11008      1   Brute Force        Marbon
# 1   6/29/2024  Wildcard     11008      1   Brute Force       Mashiro
# 2   6/29/2024  Wildcard     11008      1   Brute Force        Kodjik
# 3   6/29/2024  Wildcard     11008      1   Brute Force        Fangor
# 4   6/29/2024  Wildcard     11008      1   Brute Force    blackMarch
# ..        ...       ...       ...    ...           ...           ...
# 85  6/30/2024  Wildcard     11013      4       Entity7      Markinho
# 86  6/30/2024  Wildcard     11013      4       Entity7  Hide on bush
# 87  6/30/2024  Wildcard     11013      4       Entity7          Chan
# 88  6/30/2024  Wildcard     11013      4       Entity7         Erwin
# 89  6/30/2024  Wildcard     11013      4       Entity7         Furyy
#
#          Pick   Win            Enemy      Role Pick  ...  K  D  A   Gold  \
# 0      X.Borg   Win  Trained to Kill        Fighter  ...  3  3  5  10925
# 1    Fredrinn   Win  Trained to Kill   Fighter/Tank  ...  2  2  7  10039
# 2   Valentina   Win  Trained to Kill           Mage  ...  3  2  7   9523
# 3       Hilda   Win  Trained to Kill   Tank/Fighter  ...  2  4  4   8409
# 4      Moskov   Win  Trained to Kill       Marksman  ...  1  2  4  11687
# ..        ...   ...              ...            ...  ... .. .. ..    ...
# 85      Edith  Lose         HomeBois  Tank/Marksman  ...  0  4  3   7338
# 86     Karina  Lose         HomeBois       Assassin  ...  1  3  3   8606
# 87      Lunox  Lose         HomeBois           Mage  ...  6  1  1  10552
# 88      Grock  Lose         HomeBois   Tank/Fighter  ...  0  3  5   6944
# 89      Clint  Lose         HomeBois       Marksman  ...  1  5  1   8847
#
#    Level Turtle Lord  Tower  Buff\n Biru  Buff \nMerah
# 0     15      2     1     6            9             9
# 1     15      2     1     6            9             9
# 2     15      2     1     6            9             9
# 3     15      2     1     6            9             9
# 4     15      2     1     6            9             9
# ..   ...    ...   ...   ...          ...           ...
# 85    12      1     0     3            6             6
# 86    14      1     0     3            6             6
# 87    14      1     0     3            6             6
# 88    12      1     0     3            6             6
# 89    13      1     0     3            6             6
#
# [90 rows x 28 columns]
