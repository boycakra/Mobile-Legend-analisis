# %%
import pygal
from pygal.style import LightSolarizedStyle
from collections import defaultdict
from statistics import mean

# Data
data = {
    'Team': ['HomeBois', 'HomeBois', 'HomeBois', 'HomeBois', 'HomeBois', 'Entity7', 'Entity7', 'Entity7', 'Entity7', 'Entity7'],
    'Player': ['Sepat', 'Chibi', 'Udil', 'Xorn', 'Nets', 'Markinho', 'Hide on bush', 'Chan', 'Erwin', 'Furyy'],
    'Pick': ['Terizla', 'Ling', 'Valentina', 'Chou', 'Bruno', 'Edith', 'Karina', 'Lunox', 'Grock', 'Clint'],
    'Role': ['Exp-lane', 'Jungler-line', 'Mid-lane', 'Roamer-lane', 'gold-lane', 'Exp-lane', 'Jungler-line', 'Mid-lane', 'Roamer-lane', 'gold-lane'],
    'K': [4, 7, 3, 0, 2, 0, 1, 6, 0, 1],
    'D': [1, 3, 3, 0, 1, 4, 3, 1, 3, 5],
    'A': [5, 5, 9, 7, 5, 3, 3, 1, 5, 1],
    'Gold': [8332, 12240, 8810, 6556, 11359, 7338, 8606, 10552, 6944, 8847],
    'Level': [14, 15, 15, 13, 15, 12, 14, 14, 12, 13]
}

# Function to calculate ratios relative to each metric
def calculate_ratios(data):
    ratios = defaultdict(lambda: defaultdict(float))
    
    for i in range(len(data['Player'])):
        for metric in ['K', 'D', 'A', 'Gold', 'Level']:
            player_value = data[metric][i]
            ratios[data['Player'][i]][metric] = player_value
    
    return ratios

# Calculate average metrics for each role and team
def calculate_averages(data):
    role_averages = defaultdict(lambda: defaultdict(list))
    team_averages = defaultdict(lambda: defaultdict(list))
    
    for i in range(len(data['Player'])):
        role = data['Role'][i]
        team = data['Team'][i]
        for metric in ['K', 'D', 'A', 'Gold', 'Level']:
            role_averages[role][metric].append(data[metric][i])
            team_averages[team][metric].append(data[metric][i])
    
    for role in role_averages:
        for metric in role_averages[role]:
            role_averages[role][metric] = mean(role_averages[role][metric])
    
    for team in team_averages:
        for metric in team_averages[team]:
            team_averages[team][metric] = mean(team_averages[team][metric])
    
    return role_averages, team_averages

# Calculate ratios and averages
ratios = calculate_ratios(data)
role_averages, team_averages = calculate_averages(data)

# Initialize radar chart with custom style and background color
radar_chart = pygal.Radar(width=600, height=400, style=LightSolarizedStyle, background='transparent')

# Define metrics and labels
metrics = ['K', 'D', 'A', 'Gold', 'Level']
radar_chart.x_labels = metrics

# Find maximum values for normalization
max_values = {metric: max(data[metric]) for metric in metrics}

# Add each player's data for each metric
for player in ratios:
    player_data = [ratios[player][metric] / max_values[metric] for metric in metrics]
    raw_data = [ratios[player][metric] for metric in metrics]
    radar_chart.add(player, [{'value': player_data[i], 'label': f'{metrics[i]}: {player_data[i]:.2f} (Raw: {raw_data[i]})'} for i in range(len(metrics))], fill=True)

# Add average data for roles and teams
for role in role_averages:
    role_data = [role_averages[role][metric] / max_values[metric] for metric in metrics]
    raw_role_data = [role_averages[role][metric] for metric in metrics]
    radar_chart.add(f'Avg Role: {role}', [{'value': role_data[i], 'label': f'{metrics[i]}: {role_data[i]:.2f} (Raw: {raw_role_data[i]})'} for i in range(len(metrics))], stroke_style={'width': 1.5, 'dasharray': '5, 5'})

for team in team_averages:
    team_data = [team_averages[team][metric] / max_values[metric] for metric in metrics]
    raw_team_data = [team_averages[team][metric] for metric in metrics]
    radar_chart.add(f'Avg Team: {team}', [{'value': team_data[i], 'label': f'{metrics[i]}: {team_data[i]:.2f} (Raw: {raw_team_data[i]})'} for i in range(len(metrics))], stroke_style={'width': 1.5, 'dasharray': '2, 2'})

# Render the radar chart
radar_chart.render_in_browser()
# Out:
# file://C:/Users/BOYCAK~1/AppData/Local/Temp/tmpovmpstfu.html

# %%
import pygal
from pygal.style import LightSolarizedStyle
from collections import defaultdict
from statistics import mean
import pandas as pd

# Data
data = {
    'Team': ['HomeBois', 'HomeBois', 'HomeBois', 'HomeBois', 'HomeBois', 'Entity7', 'Entity7', 'Entity7', 'Entity7', 'Entity7'],
    'Player': ['Sepat', 'Chibi', 'Udil', 'Xorn', 'Nets', 'Markinho', 'Hide on bush', 'Chan', 'Erwin', 'Furyy'],
    'Pick': ['Terizla', 'Ling', 'Valentina', 'Chou', 'Bruno', 'Edith', 'Karina', 'Lunox', 'Grock', 'Clint'],
    'Role': ['Exp-lane', 'Jungler-line', 'Mid-lane', 'Roamer-lane', 'gold-lane', 'Exp-lane', 'Jungler-line', 'Mid-lane', 'Roamer-lane', 'gold-lane'],
    'K': [4, 7, 3, 0, 2, 0, 1, 6, 0, 1],
    'D': [1, 3, 3, 0, 1, 4, 3, 1, 3, 5],
    'A': [5, 5, 9, 7, 5, 3, 3, 1, 5, 1],
    'Gold': [8332, 12240, 8810, 6556, 11359, 7338, 8606, 10552, 6944, 8847],
    'Level': [14, 15, 15, 13, 15, 12, 14, 14, 12, 13]
}

# Function to calculate ratios relative to each metric
def calculate_ratios(data):
    ratios = defaultdict(lambda: defaultdict(float))
    
    for i in range(len(data['Player'])):
        for metric in ['K', 'D', 'A', 'Gold', 'Level']:
            player_value = data[metric][i]
            ratios[data['Player'][i]][metric] = player_value
    
    return ratios

# Calculate average metrics for each role and team
def calculate_averages(data):
    role_averages = defaultdict(lambda: defaultdict(list))
    team_averages = defaultdict(lambda: defaultdict(list))
    
    for i in range(len(data['Player'])):
        role = data['Role'][i]
        team = data['Team'][i]
        for metric in ['K', 'D', 'A', 'Gold', 'Level']:
            role_averages[role][metric].append(data[metric][i])
            team_averages[team][metric].append(data[metric][i])
    
    for role in role_averages:
        for metric in role_averages[role]:
            role_averages[role][metric] = mean(role_averages[role][metric])
    
    for team in team_averages:
        for metric in team_averages[team]:
            team_averages[team][metric] = mean(team_averages[team][metric])
    
    return role_averages, team_averages

# Calculate ratios and averages
ratios = calculate_ratios(data)
role_averages, team_averages = calculate_averages(data)

# Initialize radar chart with custom style and background color
radar_chart = pygal.Radar(style=LightSolarizedStyle, background='transparent', legend_at_bottom=True)

# Define metrics and labels
metrics = ['K', 'D', 'A', 'Gold', 'Level']
radar_chart.x_labels = metrics

# Find maximum values for normalization
max_values = {metric: max(data[metric]) for metric in metrics}

# Add each player's data for each metric
for player in ratios:
    player_data = [ratios[player][metric] / max_values[metric] for metric in metrics]
    raw_data = [ratios[player][metric] for metric in metrics]
    radar_chart.add(player, [{'value': player_data[i], 'label': f'{metrics[i]}: {player_data[i]:.2f} (Raw: {raw_data[i]})'} for i in range(len(metrics))], fill=True)

# Add average data for roles and teams
for role in role_averages:
    role_data = [role_averages[role][metric] / max_values[metric] for metric in metrics]
    raw_role_data = [role_averages[role][metric] for metric in metrics]
    radar_chart.add(f'Avg Role: {role}', [{'value': role_data[i], 'label': f'{metrics[i]}: {role_data[i]:.2f} (Raw: {raw_role_data[i]})'} for i in range(len(metrics))], stroke_style={'width': 1.5, 'dasharray': '5, 5'})

for team in team_averages:
    team_data = [team_averages[team][metric] / max_values[metric] for metric in metrics]
    raw_team_data = [team_averages[team][metric] for metric in metrics]
    radar_chart.add(f'Avg Team: {team}', [{'value': team_data[i], 'label': f'{metrics[i]}: {team_data[i]:.2f} (Raw: {raw_team_data[i]})'} for i in range(len(metrics))], stroke_style={'width': 1.5, 'dasharray': '2, 2'})

# Render the radar chart (smaller size)
radar_chart.render_in_browser(width=500, height=400)


# Create DataFrame
df1_data = []

for player in ratios:
    raw_metrics = [ratios[player][metric] for metric in metrics]
    norm_metrics = [ratios[player][metric] / max_values[metric] for metric in metrics]
    df1_data.append({
        'Player': player,
        'Team': data['Team'][data['Player'].index(player)],
        'Raw metric': str(raw_metrics),
        'Normalization metric': str(norm_metrics)
    })

df1 = pd.DataFrame(df1_data)
df1
# Out:
# file://C:/Users/BOYCAK~1/AppData/Local/Temp/tmpgy63vjox.html
#          Player      Team            Raw metric  \
# 0         Sepat  HomeBois   [4, 1, 5, 8332, 14]
# 1         Chibi  HomeBois  [7, 3, 5, 12240, 15]
# 2          Udil  HomeBois   [3, 3, 9, 8810, 15]
# 3          Xorn  HomeBois   [0, 0, 7, 6556, 13]
# 4          Nets  HomeBois  [2, 1, 5, 11359, 15]
# 5      Markinho   Entity7   [0, 4, 3, 7338, 12]
# 6  Hide on bush   Entity7   [1, 3, 3, 8606, 14]
# 7          Chan   Entity7  [6, 1, 1, 10552, 14]
# 8         Erwin   Entity7   [0, 3, 5, 6944, 12]
# 9         Furyy   Entity7   [1, 5, 1, 8847, 13]
#
#                                 Normalization metric
# 0  [0.5714285714285714, 0.2, 0.5555555555555556, ...
# 1           [1.0, 0.6, 0.5555555555555556, 1.0, 1.0]
# 2  [0.42857142857142855, 0.6, 1.0, 0.719771241830...
# 3  [0.0, 0.0, 0.7777777777777778, 0.5356209150326...
# 4  [0.2857142857142857, 0.2, 0.5555555555555556, ...
# 5  [0.0, 0.8, 0.3333333333333333, 0.5995098039215...
# 6  [0.14285714285714285, 0.6, 0.3333333333333333,...
# 7  [0.8571428571428571, 0.2, 0.1111111111111111, ...
# 8  [0.0, 0.6, 0.5555555555555556, 0.5673202614379...
# 9  [0.14285714285714285, 1.0, 0.1111111111111111,...

# %%
import pygal
from pygal.style import LightSolarizedStyle
from collections import defaultdict
from statistics import mean
import pandas as pd
from IPython.display import HTML, display
import base64

# Data
data = {
    'Team': ['HomeBois', 'HomeBois', 'HomeBois', 'HomeBois', 'HomeBois', 'Entity7', 'Entity7', 'Entity7', 'Entity7', 'Entity7'],
    'Player': ['Sepat', 'Chibi', 'Udil', 'Xorn', 'Nets', 'Markinho', 'Hide on bush', 'Chan', 'Erwin', 'Furyy'],
    'Pick': ['Terizla', 'Ling', 'Valentina', 'Chou', 'Bruno', 'Edith', 'Karina', 'Lunox', 'Grock', 'Clint'],
    'Role': ['Exp-lane', 'Jungler-line', 'Mid-lane', 'Roamer-lane', 'gold-lane', 'Exp-lane', 'Jungler-line', 'Mid-lane', 'Roamer-lane', 'gold-lane'],
    'K': [4, 7, 3, 0, 2, 0, 1, 6, 0, 1],
    'D': [1, 3, 3, 0, 1, 4, 3, 1, 3, 5],
    'A': [5, 5, 9, 7, 5, 3, 3, 1, 5, 1],
    'Gold': [8332, 12240, 8810, 6556, 11359, 7338, 8606, 10552, 6944, 8847],
    'Level': [14, 15, 15, 13, 15, 12, 14, 14, 12, 13]
}

# Function to calculate ratios relative to each metric
def calculate_ratios(data):
    ratios = defaultdict(lambda: defaultdict(float))
    
    for i in range(len(data['Player'])):
        for metric in ['K', 'D', 'A', 'Gold', 'Level']:
            player_value = data[metric][i]
            ratios[data['Player'][i]][metric] = player_value
    
    return ratios

# Calculate average metrics for each role and team
def calculate_averages(data):
    role_averages = defaultdict(lambda: defaultdict(list))
    team_averages = defaultdict(lambda: defaultdict(list))
    
    for i in range(len(data['Player'])):
        role = data['Role'][i]
        team = data['Team'][i]
        for metric in ['K', 'D', 'A', 'Gold', 'Level']:
            role_averages[role][metric].append(data[metric][i])
            team_averages[team][metric].append(data[metric][i])
    
    for role in role_averages:
        for metric in role_averages[role]:
            role_averages[role][metric] = mean(role_averages[role][metric])
    
    for team in team_averages:
        for metric in team_averages[team]:
            team_averages[team][metric] = mean(team_averages[team][metric])
    
    return role_averages, team_averages

# Calculate ratios and averages
ratios = calculate_ratios(data)
role_averages, team_averages = calculate_averages(data)

# Initialize radar chart with custom style and background color
radar_chart = pygal.Radar(style=LightSolarizedStyle, background='transparent', show_legend=False)

# Define metrics and labels
metrics = ['K', 'D', 'A', 'Gold', 'Level']
radar_chart.x_labels = metrics

# Find maximum values for normalization
max_values = {metric: max(data[metric]) for metric in metrics}

# Function to add data to radar chart
def add_data_to_radar_chart(chart, data, label, normalize=True, fill=True, stroke_style=None):
    for player in data:
        player_data = [data[player][metric] / max_values[metric] if normalize else data[player][metric] for metric in metrics]
        chart.add(player, [{'value': player_data[i], 'label': f'{metrics[i]}: {player_data[i]:.2f}' if normalize else f'{metrics[i]}: {player_data[i]}' } for i in range(len(metrics))], fill=fill, stroke_style=stroke_style)

# Add each player's data
add_data_to_radar_chart(radar_chart, ratios, 'Player', normalize=True, fill=True)

# Save radar chart as SVG string
radar_chart_data = radar_chart.render()

# Encode SVG data to base64
base64_chart = base64.b64encode(radar_chart_data).decode('utf-8')

# Display radar chart embedded in notebook
html_embed = f'<embed type="image/svg+xml" src="data:image/svg+xml;base64,{base64_chart}" style="max-width:100%; height:auto;" />'
display(HTML(html_embed))
# Out:
# <embed type="image/svg+xml" src="data:image/svg+xml;base64,..." style="max-width:100%; height:auto;" />

# %%
import pygal
from pygal.style import LightSolarizedStyle
from collections import defaultdict
from statistics import mean
import pandas as pd

# Data
data = {
    'Team': ['HomeBois', 'HomeBois', 'HomeBois', 'HomeBois', 'HomeBois', 'Entity7', 'Entity7', 'Entity7', 'Entity7', 'Entity7'],
    'Player': ['Sepat', 'Chibi', 'Udil', 'Xorn', 'Nets', 'Markinho', 'Hide on bush', 'Chan', 'Erwin', 'Furyy'],
    'Pick': ['Terizla', 'Ling', 'Valentina', 'Chou', 'Bruno', 'Edith', 'Karina', 'Lunox', 'Grock', 'Clint'],
    'Role': ['Exp-lane', 'Jungler-line', 'Mid-lane', 'Roamer-lane', 'gold-lane', 'Exp-lane', 'Jungler-line', 'Mid-lane', 'Roamer-lane', 'gold-lane'],
    'K': [4, 7, 3, 0, 2, 0, 1, 6, 0, 1],
    'D': [1, 3, 3, 0, 1, 4, 3, 1, 3, 5],
    'A': [5, 5, 9, 7, 5, 3, 3, 1, 5, 1],
    'Gold': [8332, 12240, 8810, 6556, 11359, 7338, 8606, 10552, 6944, 8847],
    'Level': [14, 15, 15, 13, 15, 12, 14, 14, 12, 13]
}

# Function to calculate ratios relative to each metric
def calculate_ratios(data):
    ratios = defaultdict(lambda: defaultdict(float))
    
    for i in range(len(data['Player'])):
        for metric in ['K', 'D', 'A', 'Gold', 'Level']:
            player_value = data[metric][i]
            ratios[data['Player'][i]][metric] = player_value
    
    return ratios

# Calculate average metrics for each role and team
def calculate_averages(data):
    role_averages = defaultdict(lambda: defaultdict(list))
    team_averages = defaultdict(lambda: defaultdict(list))
    
    for i in range(len(data['Player'])):
        role = data['Role'][i]
        team = data['Team'][i]
        for metric in ['K', 'D', 'A', 'Gold', 'Level']:
            role_averages[role][metric].append(data[metric][i])
            team_averages[team][metric].append(data[metric][i])
    
    for role in role_averages:
        for metric in role_averages[role]:
            role_averages[role][metric] = mean(role_averages[role][metric])
    
    for team in team_averages:
        for metric in team_averages[team]:
            team_averages[team][metric] = mean(team_averages[team][metric])
    
    return role_averages, team_averages

# Calculate ratios and averages
ratios = calculate_ratios(data)
role_averages, team_averages = calculate_averages(data)

# Initialize radar chart with custom style and background color
radar_chart = pygal.Radar(width=400, height=300, style=LightSolarizedStyle, background='transparent', show_legend=False)

# Define metrics and labels
metrics = ['K', 'D', 'A', 'Gold', 'Level']
radar_chart.x_labels = metrics

# Find maximum values for normalization
max_values = {metric: max(data[metric]) for metric in metrics}

# Add each player's data for each metric
for player in ratios:
    player_data = [ratios[player][metric] / max_values[metric] for metric in metrics]
    radar_chart.add(player, [{'value': player_data[i], 'label': f'{metrics[i]}: {player_data[i]:.2f}'} for i in range(len(metrics))], fill=True)

# Add average data for roles and teams
for role in role_averages:
    role_data = [role_averages[role][metric] / max_values[metric] for metric in metrics]
    radar_chart.add(f'Avg Role: {role}', [{'value': role_data[i], 'label': f'{metrics[i]}: {role_data[i]:.2f}'} for i in range(len(metrics))], stroke_style={'width': 1.5, 'dasharray': '5, 5'})

for team in team_averages:
    team_data = [team_averages[team][metric] / max_values[metric] for metric in metrics]
    radar_chart.add(f'Avg Team: {team}', [{'value': team_data[i], 'label': f'{metrics[i]}: {team_data[i]:.2f}'} for i in range(len(metrics))], stroke_style={'width': 1.5, 'dasharray': '2, 2'})

# Render the radar chart (smaller size)
radar_chart.render_to_file('radar_chart.svg')

# Create DataFrame
df1_data = []

for player in ratios:
    raw_metrics = [ratios[player][metric] for metric in metrics]
    norm_metrics = [ratios[player][metric] / max_values[metric] for metric in metrics]
    df1_data.append({
        'Player': player,
        'Team': data['Team'][data['Player'].index(player)],
        'Raw metric': str(raw_metrics),
        'Normalization metric': str(norm_metrics)
    })

df1 = pd.DataFrame(df1_data)
print(df1)
# Out:
#          Player      Team            Raw metric  \
# 0         Sepat  HomeBois   [4, 1, 5, 8332, 14]
# 1         Chibi  HomeBois  [7, 3, 5, 12240, 15]
# 2          Udil  HomeBois   [3, 3, 9, 8810, 15]
# 3          Xorn  HomeBois   [0, 0, 7, 6556, 13]
# 4          Nets  HomeBois  [2, 1, 5, 11359, 15]
# 5      Markinho   Entity7   [0, 4, 3, 7338, 12]
# 6  Hide on bush   Entity7   [1, 3, 3, 8606, 14]
# 7          Chan   Entity7  [6, 1, 1, 10552, 14]
# 8         Erwin   Entity7   [0, 3, 5, 6944, 12]
# 9         Furyy   Entity7   [1, 5, 1, 8847, 13]
#
#                                 Normalization metric
# 0  [0.5714285714285714, 0.2, 0.5555555555555556, ...
# 1           [1.0, 0.6, 0.5555555555555556, 1.0, 1.0]
# 2  [0.42857142857142855, 0.6, 1.0, 0.719771241830...
# 3  [0.0, 0.0, 0.7777777777777778, 0.5356209150326...
# 4  [0.2857142857142857, 0.2, 0.5555555555555556, ...
# 5  [0.0, 0.8, 0.3333333333333333, 0.5995098039215...
# 6  [0.14285714285714285, 0.6, 0.3333333333333333,...
# 7  [0.8571428571428571, 0.2, 0.1111111111111111, ...
# 8  [0.0, 0.6, 0.5555555555555556, 0.5673202614379...
# 9  [0.14285714285714285, 1.0, 0.1111111111111111,...
